# %% [markdown]
# ### Reading Data

# %%
import pandas as pd

# %%
df = pd.read_excel(r"H:\CampusX_DS\week43 - My Projects Aug 2024\used_car_price_prediction\Used-Car-Price-Prediction\src\notebook\data\cars24_final_data.xlsx")

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Data Summary

# %%
cols = df.columns.tolist()

# %%
for col in cols:
    print(df[col].sample(7))
# Out:
# 99      10533635785
# 1067    10177635723
# 4511    11327634739
# 1332    10515533786
# 175     11273386748
# 4565    11346833714
# 3596    10367936743
# Name: content.appointmentId, dtype: int64
# 1986     Maruti
# 536        Tata
# 992      Maruti
# 142     Hyundai
# 2919      Honda
# 102         KIA
# 3234     Maruti
# Name: content.make, dtype: object
# 330        Eon
# 4204    SELTOS
# 991     XUV500
# 2103     Tiago
# 2466     Amaze
# 4617     Tiago
# 1682     Rapid
# Name: content.model, dtype: object
# 1359         TITANIUM 1.5L PETROL
# 3688            1.2L I-VTEC V CVT
# 215             XM SUNROOF PETROL
# 3415    SPORTZ AMT 1.2 KAPPA VTVT
# 1723              ZETA PETROL 1.2
# 1169            1.2L I-VTEC VX MT
# 3013        SX PLUS 1.0 TURBO DCT
# Name: content.variant, dtype: object
# 262     2017
# 1234    2017
# 2177    2019
# 1439    2020
# 1310    2020
# 2777    2018
# 1928    2011
# Name: content.year, dtype: int64
# 2644       Manual
# 2833    Automatic
# ...

# %% [markdown]
# 1. content.appointmentId: unique id for every car
# 2. content.make: car make like tata, maruti, hyundai etc
# 3. content.model: car model
# 4. content.variant: variant of the car
# 5. content.year: build year
# 6. content.transmission: whether manual or automatic
# 7. content.bodyType: Sedan, hatchback etc
# 8. content.fuelType: petrol, diesel etc
# 9. content.ownerNumber: 1st owner or 2nd owner etc
# 10. content.odometerReading: km reading
# 11. content.cityRto: rto info
# 12. content.registrationNumber: car number
# 13. content.listingPrice: listing price
# 14. content.onRoadPrice: on road price, The on-road price of a car is the final price, while the listing price, also known as the ex-showroom price, is not the final price
# 15. content.fitnessUpto: car number validity
# 16. content.insuranceType: type of insurance
# 17. content.insuranceExpiry: insurance expiry date
# 18. content.lastServicedAt: last serviced date
# 19. content.duplicateKey: whether car duplicate key is available
# 20. content.city: car registration city
# 21. 12V Power Outlet: whether available or not
# 22. ABS - Anti-lock Braking System
# 23. Air Conditioner
# 24. Airbags: count of airbags
# 25. Android Auto
# 26. Apple CarPlay
# 27. Audio System
# 28. Bluetooth Compatibility
# 29. Bootspace (litres)
# 30. Central Locking
# 31. Cruise control
# 32. Cylinders: Cylinder count
# 33. DRL - Daytime Running Lights
# 34. Displacement (cc)
# 35. EBD - Electronic Brakeforce Distribution
# 36. Electrically Foldable Mirrors
# 37. Emission Standard
# 38. Front Fog Lights
# 39. Fueltank Capacity (litres)
# 40. Gear Box - Number Of Gears
# 41. Ground Clearance (mm)
# 42. Headlamp Bulb Type - High Beam
# 43. Headlamp Bulb Type - Low Beam
# 44. Headlamp Lens Type
# 45. Hill Descent Control
# 46. Hill Hold Control
# 47. ISOFIX - Child Seat Anchor Points
# 48. Instrument Panel Type
# 49. Length (mm) - length of car
# 50. Max Power (bhp)
# 51. Max Power (rpm)
# 52. Max Torque (Nm)
# 53. Multi-function Display Screen
# 54. Multi-function Display Screen Size (in)
# 55. Number Of Disc Brakes
# 56. Number Of Speakers
# 57. Parking Assist - Rear
# 58. Power Windows - Front
# 59. Power Windows - Rear
# 60. Push Button Start
# 61. Rear AC
# 62. Rear Defogger
# 63. Remote Trunk Release
# 64. Rim Type - Front Wheels
# 65. Rim Type - Rear Wheels
# 66. Seat Upholstery
# 67. Seating Capacity
# 68. Smart Card/Smart Key
# 69. Speaker Brand
# 70. Steering Adjustment
# 71. Steering Mounted Controls
# 72. Steering Wheel Material
# 73. Sunroof Type
# 74. Sunroof/Moonroof
# 75. TPMS - Tyre Pressure Monitoring System
# 76. Traction Control (TCS) is a safety feature that helps prevent a car's wheels from losing grip on the road.
# 77. Transmission Type (duplicate with content.transmission)
# 78. USB Connection - Front
# 79. Ventilated Seats - Front
# 80. Voice Recognition
# 81. Wheel Base (mm)
# 82. Width (mm) - width of car
# 83. Wireless Charging Pad
# 84. Entertainment Display Screen
# 85. Entertainment Display Screen Size (in)
# 86. GPS Navigation System
# 87. NCAP Rating: NCAP ratings are a way to evaluate the safety of a vehicle
# 88. USB Connection - Rear
# 89. 360 Degree Camera
# 90. Ambient Lighting
# 91. Driver Seat Adjustment - Electric
# 92. HVAC stands for heating, ventilation, and air conditioning, and it's the climate control system in a car
# 93. Parking Assist - Front
# 94. Parking Assist - Side
# 95. Ventilated Seats - Rear
# 96. Back/Rear
# 97. Buy With Confidence
# 98. Dashboard
# 99. Details
# 100. Front
# 101. Left Side
# 102. Our quality promise
# 103. Right Front Diagonal
# 104. Right Side Front Door Cabin
# 105. Right Side Rear Door Cabin
# 106. Top Features

# %%
df[['content.transmission','Transmission Type']].sample(7)
# Out:
#      content.transmission                      Transmission Type
# 2116            Automatic     Continuously Variable Transmission
# 4026            Automatic  Manual Sequential With Automatic Mode
# 4137               Manual                                 Manual
# 3224               Manual                                 Manual
# 4121               Manual                                 Manual
# 2739               Manual                                 Manual
# 3033               Manual                                 Manual

# %% [markdown]
# ##### we can delete the 'Transmission Type' column due to duplicate data

# %%
df.drop(columns = ['Transmission Type'], inplace=True)

# %%
df[['content.cityRto', 'content.registrationNumber','content.city']]
# Out:
#      content.cityRto content.registrationNumber content.city
# 0               HR26                 HR26EK8451        Noida
# 1               HR51                 HR51BU6635    Faridabad
# 2               HR98                  HR98D1809      Gurgaon
# 3               DL8C                  DL8CY3151        Noida
# 4               UP32                 UP32MJ0537        Noida
# 5               DL3C                 DL3CCX2133    Ghaziabad
# 6               HR29                 HR29AV6931    Faridabad
# 7               HR51                 HR51CK5382      Gurgaon
# 8               HR26                 HR26EW9829      Gurgaon
# 9               HR98                  HR98J7588      Gurgaon
# 10              HR26                 HR26EZ4090      Gurgaon
# 11              HR26                 HR26DR4220      Gurgaon
# 12              HR26                 HR26EJ9071      Gurgaon
# 13              DL11                 DL11CD4946    New Delhi
# ...

# %% [markdown]
# ##### we can delete 'content.registrationNumber' since it is of no use

# %%
df.drop(columns = ['content.registrationNumber'], inplace=True)

# %% [markdown]
# ##### we can remove listing price since on-road price of a car is the final price, while the listing price, also known as the ex-showroom price, is not the final price

# %%
df.drop(columns = ['content.listingPrice'], inplace=True)

# %% [markdown]
# ### Data Validation
#
# - validate if scraped data is correct or not
# - validte NaNs if they are correct
# - Also check what each column means by referring to the website

# %%
df.sample(7)
# Out:
#       content.appointmentId content.make content.model   content.variant  \
# 1717            10156289762       Maruti          Ciaz               ZXI
# 3024            11438831773       Maruti          Alto               LXI
# 4071            14085132723       Maruti          Ritz               ZDI
# 4564            11377789772        Honda          Jazz    1.2L I-VTEC SV
# 3931            10227632715        Skoda         Rapid  1.6 MPI STYLE AT
# 4230            10274530786       Maruti        Baleno  DELTA PETROL 1.2
# 436             10098532782       Maruti       Celerio       ZXI AMT (O)
#
#       content.year content.transmission content.bodyType content.fuelType  \
# 1717          2016               Manual            Sedan           Petrol
# 3024          2019               Manual        Hatchback           Petrol
# 4071          2015               Manual        Hatchback           Diesel
# 4564          2017               Manual        Hatchback           Petrol
# ...

# %%
df[df['Back/Rear'] == 'Plastic']
# Out:
#       content.appointmentId content.make content.model       content.variant  \
# 497             10084183741      Hyundai     Grand i10  MAGNA 1.2 KAPPA VTVT
# 1055            10084183741      Hyundai     Grand i10  MAGNA 1.2 KAPPA VTVT
# 1264            10084183741      Hyundai     Grand i10  MAGNA 1.2 KAPPA VTVT
# 1577            10084183741      Hyundai     Grand i10  MAGNA 1.2 KAPPA VTVT
# 1751            10084183741      Hyundai     Grand i10  MAGNA 1.2 KAPPA VTVT
# 2162            10084183741      Hyundai     Grand i10  MAGNA 1.2 KAPPA VTVT
# 2602            10084183741      Hyundai     Grand i10  MAGNA 1.2 KAPPA VTVT
# 2780            10084183741      Hyundai     Grand i10  MAGNA 1.2 KAPPA VTVT
# 4716            17891634736      Hyundai     Grand i10  MAGNA 1.2 KAPPA VTVT
#
#       content.year content.transmission content.bodyType content.fuelType  \
# 497           2017               Manual        Hatchback           Petrol
# ...

# %% [markdown]
# ##### remove these columns as unable to identify what does this value means

# %%
df.drop(columns=['Back/Rear','Buy With Confidence','Dashboard'], inplace=True)

# %%
df['Details'].value_counts()
# Out:
# 1.0    13
# Name: Details, dtype: int64

# %% [markdown]
# ##### remove these columns as unable to idenfity what does this column value means

# %%
df.drop(columns=['Details','Front','Left Side','Our quality promise','Right Front Diagonal'], inplace=True)

# %%
df.drop(columns=['Top Features'], inplace=True)

# %%
df.drop(columns=['Right Side Front Door Cabin','Right Side Rear Door Cabin'], inplace=True)

# %%
df.shape
# Out:
# (4833, 92)

# %%
df.head()
# Out:
#    content.appointmentId content.make content.model    content.variant  \
# 0            11222930736      Hyundai         Verna        SX 1.5 CRDI
# 1            11055331783       Maruti      Alto K10                VXI
# 2            10100134753         Tata         Tiago        XZ PLUS CNG
# 3            10063035782       Maruti       Celerio            VXI AMT
# 4            10138531732        Honda          WR-V  1.2L I-VTEC VX MT
#
#    content.year content.transmission content.bodyType content.fuelType  \
# 0          2020               Manual            Sedan           Diesel
# 1          2018               Manual        Hatchback           Petrol
# 2          2022               Manual        Hatchback              CNG
# 3          2016            Automatic        Hatchback           Petrol
# 4          2021               Manual              SUV           Petrol
#
#    content.ownerNumber  content.odometerReading content.cityRto  \
# ...

# %%
df['Parking Assist - Side'].value_counts()
# Out:
# Camera    89
# Name: Parking Assist - Side, dtype: int64

# %%
df[df['Parking Assist - Side'] == 'Camera']
# Out:
#       content.appointmentId content.make content.model  \
# 14              10031336737           MG        HECTOR
# 34              10151535723       Maruti           XL6
# 36              10139132723       Maruti           XL6
# 126             10128484733          KIA        SELTOS
# 135             10080556716           MG        HECTOR
# 150             10038682724           MG        HECTOR
# 177             10005855757       Nissan       MAGNITE
# 179             11288986723       Maruti        Baleno
# 186             10084738793          KIA        SELTOS
# 192             10029086743           MG        HECTOR
# 201             10137036784       Nissan       MAGNITE
# 203             10010288709          KIA        SELTOS
# 208             11220136783          KIA        SELTOS
# 277             11210054781       Nissan       MAGNITE
# 331             10165736783       Nissan       MAGNITE
# 379             10175639780           MG        HECTOR
# ...

# %% [markdown]
# ##### Now data looks good, we can start assesing data: Find issues with data & note down to fix it

# %% [markdown]
# ### Data Assesment
#
# - There are 2 types of assesments:
#     1. Manual: Looking through data manually on excel & document any issues with the data found via naked eyes
#     2. Programatic: Exploring using pandas functions df[column_name].value_counts(), head & tail, sample, info, isnull().sum(), duplicated, describe. Our aim to identify missing values, duplicated values, data correction opportunity
#
#
# - Steps of assesment
#     1. Disovery
#     2. Document
#
# - Issues with data
#     1. Dirty data
#     2. Messy Data

# %% [markdown]
# #### date: 30-sep-2024
